# %%
from smolagents import CodeAgent
from smolagents.cli import load_model
from utils import instrument
from dotenv import load_dotenv

load_dotenv()
instrument("smolagents_stock_analyser")

def main():
    model = load_model("LiteLLMModel", "azure/gpt-4.1-mini")
    agent = CodeAgent(tools=[], model=model, additional_authorized_imports= "*", add_base_tools=True, verbosity_level=2)
    agent.run(
        "Please analyze Microsoft's stock trend over the last 30 days, create a chart to visualize the data, and save the chart to disk.",
    )

if __name__ == "__main__":
    main()
# Out:
# Overriding of current TracerProvider is not allowed
# Attempting to instrument while already instrumented
# 🔭 OpenTelemetry Tracing Details 🔭
# |  Phoenix Project: smolagents_stock_analyser
# |  Span Processor: SimpleSpanProcessor
# |  Collector Endpoint: https://app.phoenix.arize.com/v1/traces
# |  Transport: HTTP + protobuf
# |  Transport Headers: {'api_key': '****'}
# |
# |  Using a default SpanProcessor. `add_span_processor` will overwrite this default.
# |
# |  ⚠️ WARNING: It is strongly advised to use a BatchSpanProcessor in production environments.
# |
# |  `register` has set this TracerProvider as the global OpenTelemetry default.
# |  To disable this behavior, call `register` with `set_global_tracer_provider=False`.
# Caution: you set an authorization for all imports, meaning your agent can decide to import any package it deems
# necessary. This might raise issues if the package is not installed in your environment. 0
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Please analyze Microsoft's stock trend over the last 30 days, create a chart to visualize the data, and save    │
# │ the chart to disk.                                                                                              │
# │                                                                                                                 │
# ╰─ LiteLLMModel - azure/gpt-4.1-mini ─────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: To analyze Microsoft's stock trend over the last 30 days, I need to get the stock price data for Microsoft
# (usually ticker symbol MSFT) for the last 30 days. Then I will create a chart to visualize the trend using a
# plotting library such as matplotlib. Finally, I will save the chart to disk. First, I will search for a reliable
# source or API to get the recent stock data for Microsoft.
#
# Code:
# ```py
# search_result = web_search(query="Microsoft MSFT stock price last 30 days api")
# print(search_result)
# ```<end_code>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_result = web_search(query="Microsoft MSFT stock price last 30 days api")
#   print(search_result)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Microsoft Corporation (MSFT)](https://finance.yahoo.com/quote/MSFT/history/)
# Discover historical prices for MSFT stock on Yahoo Finance. View daily, weekly or monthly format back to when
# Microsoft Corporation stock was issued.
#
# [Microsoft (MSFT) Historical Stock Price Data - Stock Analysis](https://stockanalysis.com/stocks/msft/history/)
# A complete stock price history for Microsoft Corporation (MSFT) stock, starting from its first trading day.
# Includes open, high, low, close and volume. A complete stock price history for Microsoft Corporation (MSFT) stock,
# starting from its first trading day. Includes open, high, low, close and volume. ... Apr 30, 2025: 390.05: 390.05:
# 385.45: ...
#
# [Msft Stock Price Last 30 Days | StatMuse Money](https://www.statmuse.com/money/ask/msft-stock-price-last-30-days)
# The closing price for Microsoft (MSFT) between February 1, 2025 and March 3, 2025 is $396.99, on Friday. It is down
# 3.4% in that time. The latest price is $393.72.
#
# [Microsoft (MSFT) Stock Price History & Chart Since 1986](https://wallstreetnumbers.com/stocks/msft/price)
# As of today (April 29, 2025), MSFT stock price is $394.04, with a rise of +$2.88 (+0.74%) during the most recent
# trading session on April 29, ... MSFT 30-day relative volume is 0.57. Market cap $2929.29B. MSFT market
# capitalization is $2929.29 billion. ... Over the past year, Microsoft stock has returned -$8.21 (-2.04%) On this
# page. Price; Trends;
#
# [Aletheia - Connectors | Microsoft Learn](https://learn.microsoft.com/en-us/connectors/aletheia/)
# Save your flow an ensure it is turned on. You are ready to go! Your workflow will now trigger each day at 4:30 PM,
# retrieve the closing price of Microsoft (MSFT) stock, and email it to you. You can replace Microsoft stock with any
# security of your choosing, including cryptocurrency, options, bonds, and more. Known Issues and Limitations
#
# [Microsoft (MSFT) Stock Price History Charts (NASDAQ:
# MSFT)](https://www.financecharts.com/stocks/MSFT/summary/price)
# The closing share price for Microsoft (MSFT) stock was $359.12 for Monday, April 21 2025, down 2.35% from the
# previous day. MSFT is down 8.64% over the past 30 days and down 10.43% for the past 12 months.
#
# [Historical Stock Prices for Microsoft (Nasdaq:MSFT) |
# MarketMinute](https://www.marketminute.com/quote/NQ:MSFT/historical)
# Daily Stock Prices for Microsoft (Nasdaq:MSFT), Including Open, High, Low, and Close for the past 25 years. Stocks
# News ETFs ... NASDAQ · Last Trade: Apr 22nd, 1:20 AM EDT. Quote News Press Releases Chart Historical FAQ About
# Competitors. Historical Prices For Microsoft (MSFT) Date Range: 2025-01-22 - 2025-04-22 ... Stock Market JSON API
# ...
#
# [MSFT : MICROSOFT CORPORATION - MSN Money](https://www.msn.com/en-us/money/stockdetails/msft-history/fi-a1xzim)
# Track MICROSOFT CORPORATION (MSFT) price, historical values, financial information, price forecast, and insights to
# empower your investing journey | MSN Money ... Nasdaq Stock Market • NLS real ...
#
# [MSFT Stock Price and Chart - ChartExchange](https://chartexchange.com/symbol/nasdaq-msft/)
# Live Microsoft Corp chart, MSFT stock price in real-time and MSFT historical prices. ... Last Earnings. Jul 30,
# 2024. Last Dividend. Feb 20, 2025 ... (NASDAQ:MSFT) stock price today is $367.65, and today's volume is 20,933,953.
# MSFT is down -1.066% today. The 30 day average volume is 18,407,459. MSFT market cap is 2.733T with 7,433,982,235
# ...
#
# [Microsoft Corporation (MSFT NASDAQ) stock market data APIs - EODHD](https://eodhd.com/financial-summary/MSFT.US)
# Get MSFT.US (Microsoft Corporation).Stock market data historical prices and Fundamental Data APIs in JSON and CSV
# formats. Financial Data Overview, Fundamentals, Earnings per Share (EPS),and End-of-Day historical prices.
#
# Out: None
# [Step 1: Duration 4.56 seconds| Input tokens: 2,033 | Output tokens: 114]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: There are multiple sources for Microsoft (MSFT) stock price data. Yahoo Finance provides detailed
# historical data, and the link to their historical price page for MSFT is
# https://finance.yahoo.com/quote/MSFT/history/. I can try to extract the last 30 days' closing price data from Yahoo
# Finance. I will write code to scrape or request this data. Then I will plot the trend using matplotlib and save the
# chart to disk.
#
# Code:
# ```py
# import yfinance as yf
# import matplotlib.pyplot as plt
# import datetime
#
# # Define ticker symbol for Microsoft
# ticker = "MSFT"
#
# # Define the date range for the last 30 days
# end_date = datetime.datetime.now()
# start_date = end_date - datetime.timedelta(days=30)
#
# # Download the stock data for Microsoft for the last 30 days
# msft_data = yf.download(ticker, start=start_date.strftime('%Y-%m-%d'), end=end_date.strftime('%Y-%m-%d'))
#
# # Print the data to confirm
# print(msft_data)
#
# # Plot the closing price trend
# plt.figure(figsize=(10, 6))
# plt.plot(msft_data.index, msft_data['Close'], marker='o', linestyle='-')
# plt.title('Microsoft (MSFT) Stock Closing Price Trend - Last 30 Days')
# plt.xlabel('Date')
# plt.ylabel('Closing Price (USD)')
# plt.grid(True)
# plt.xticks(rotation=45)
#
# # Save the plot to disk
# plt.savefig('msft_stock_trend_last_30_days.png')
#
# print("Chart saved as msft_stock_trend_last_30_days.png")
# ```<end_code>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   import yfinance as yf
#   import matplotlib.pyplot as plt
#   import datetime
#
#   # Define ticker symbol for Microsoft
#   ticker = "MSFT"
#
#   # Define the date range for the last 30 days
#   end_date = datetime.datetime.now()
#   start_date = end_date - datetime.timedelta(days=30)
#
#   # Download the stock data for Microsoft for the last 30 days
#   msft_data = yf.download(ticker, start=start_date.strftime('%Y-%m-%d'), end=end_date.strftime('%Y-%m-%d'))
#
#   # Print the data to confirm
#   print(msft_data)
#
#   # Plot the closing price trend
#   plt.figure(figsize=(10, 6))
#   plt.plot(msft_data.index, msft_data['Close'], marker='o', linestyle='-')
#   plt.title('Microsoft (MSFT) Stock Closing Price Trend - Last 30 Days')
#   plt.xlabel('Date')
#   plt.ylabel('Closing Price (USD)')
#   plt.grid(True)
#   plt.xticks(rotation=45)
#
#   # Save the plot to disk
#   plt.savefig('msft_stock_trend_last_30_days.png')
#
#   print("Chart saved as msft_stock_trend_last_30_days.png")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Execution logs:
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2025-04-01  382.190002  382.850006  373.230011  374.649994  19689500
# 2025-04-02  382.140015  385.079987  376.619995  377.970001  16092600
# 2025-04-03  373.109985  377.480011  369.350006  374.790009  30198000
# 2025-04-04  359.839996  374.589996  359.480011  364.130005  49209900
# 2025-04-07  357.859985  371.000000  344.790009  350.880005  50425000
# 2025-04-08  354.559998  373.649994  350.250000  368.260010  35868900
# 2025-04-09  390.489990  393.230011  353.100006  353.540009  50199700
# 2025-04-10  381.350006  383.899994  367.799988  382.059998  38024400
# 2025-04-11  388.450012  390.049988  378.890015  380.640015  23839200
# 2025-04-14  387.809998  394.649994  384.209991  393.220001  19251200
# 2025-04-15  385.730011  391.890015  384.160004  388.510010  17199900
# 2025-04-16  371.609985  381.609985  368.000000  380.670013  21967800
# 2025-04-17  367.779999  374.320007  366.890015  373.750000  20943700
# 2025-04-21  359.119995  364.480011  355.670013  362.820007  20807300
# 2025-04-22  366.820007  367.769989  359.859985  363.380005  19485000
# 2025-04-23  374.390015  380.390015  373.019989  376.059998  20545500
# 2025-04-24  387.299988  388.450012  375.190002  375.700012  22232300
# 2025-04-25  391.850006  392.160004  384.600006  387.000000  18973200
# 2025-04-28  391.160004  392.739990  386.640015  391.959991  16579400
# 2025-04-29  394.040009  395.100006  390.380005  391.299988  14974000
# 2025-04-30  395.260010  396.660004  384.440002  390.299988  35545100
# Chart saved as msft_stock_trend_last_30_days.png
#
# Out: None
# [Step 2: Duration 6.24 seconds| Input tokens: 5,266 | Output tokens: 442]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: I have successfully retrieved the last 30 days' stock price data for Microsoft and generated a line chart
# of the closing price trend. The chart has been saved to disk as "msft_stock_trend_last_30_days.png." I will now
# provide the final answer with the chart filename and a summary statement.
#
# Code:
# ```py
# final_answer({
#     "message": "Microsoft's stock closing price trend over the last 30 days has been analyzed and visualized.",
#     "chart_filename": "msft_stock_trend_last_30_days.png"
# })
# ```<end_code>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer({
#       "message": "Microsoft's stock closing price trend over the last 30 days has been analyzed and visualized.",
#       "chart_filename": "msft_stock_trend_last_30_days.png"
#   })
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: {'message': "Microsoft's stock closing price trend over the last 30 days has been analyzed and
# visualized.", 'chart_filename': 'msft_stock_trend_last_30_days.png'}
# [Step 3: Duration 2.43 seconds| Input tokens: 9,958 | Output tokens: 557]
