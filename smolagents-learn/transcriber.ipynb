# %%
from dotenv import load_dotenv
from smolagents import CodeAgent
from smolagents.cli import load_model
from custom_tools import transcribe
from utils import instrument

load_dotenv()
instrument("smolagents_transcriber")

def main():
    model = load_model("LiteLLMModel", "azure/gpt-4.1-mini")
    agent = CodeAgent(tools=[transcribe], model=model, additional_authorized_imports= "*", add_base_tools=True, verbosity_level=2)
    agent.run(
        "Listen to the first two minutes of U.S. President Trump's speech on his first 100 days from '../data/trump_100days_abc_interview.mp3' and extract the key points.",
    )

if __name__ == "__main__":
    main()
# Out:
# 🔭 OpenTelemetry Tracing Details 🔭
# |  Phoenix Project: smolagents_transcriber
# |  Span Processor: SimpleSpanProcessor
# |  Collector Endpoint: https://app.phoenix.arize.com/v1/traces
# |  Transport: HTTP + protobuf
# |  Transport Headers: {'api_key': '****'}
# |
# |  Using a default SpanProcessor. `add_span_processor` will overwrite this default.
# |
# |  ⚠️ WARNING: It is strongly advised to use a BatchSpanProcessor in production environments.
# |
# |  `register` has set this TracerProvider as the global OpenTelemetry default.
# |  To disable this behavior, call `register` with `set_global_tracer_provider=False`.
# Caution: you set an authorization for all imports, meaning your agent can decide to import any package it deems
# necessary. This might raise issues if the package is not installed in your environment. 0
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Listen to the first two minutes of U.S. President Trump's speech on his first 100 days from                     │
# │ '../data/trump_100days_abc_interview.mp3' and extract the key points.                                           │
# │                                                                                                                 │
# ╰─ LiteLLMModel - azure/gpt-4.1-mini ─────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: To extract the key points from President Trump's speech on his first 100 days, I will first transcribe the
# first 2 minutes (120 seconds) of the audio file provided using the transcribe tool. Then I will analyze the
# transcription for key points.
#
# Code:
# ```py
# transcription = transcribe(filepath_or_url="../data/trump_100days_abc_interview.mp3", end_seconds=120)
# print(transcription)
# ```<end_code>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   transcription = transcribe(filepath_or_url="../data/trump_100days_abc_interview.mp3", end_seconds=120)
#   print(transcription)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# Well, you said something a couple weeks ago that struck me. You said concerning the tariffs, which economists say
# are going to raise prices, you said, quote, hang tough, it won't be easy. You said that to the American people. Is
# that what Americans should expect? Some hard times? I've said that during my campaign. Look, we won a campaign by a
# lot. We won all seven swing states. We won the popular vote by a lot. You know, we had a tremendous campaign. I
# said all these things during my campaign. I said, you're going to have a transition period. We've been ripped off
# by every country all over the world. They're laughing at us. They thought we were stupid people, and we were. And I
# said, that's not going to happen. We're not going to let that happen. Hard times are ahead? I don't think so. I
# think great times are ahead. Look, since I came in, gasoline is down, groceries are down, egg prices are down, many
# things are down, just about everything. You know, you don't have the drop in fuel and energy and oil like we did. I
# took it from maybe $3.20, maybe more than that, down into a much lower number. When you have that kind of a drop,
# you're not going to have inflation. Not now, but it's the tariffs, right? We still have 145% tariffs on China. Your
# Treasury Secretary said we basically have an embargo on China. Look, you're trying to say something's going to
# happen, Terry. No, no. Nothing's going to happen. You know business. I want to ask you. I do know business. Yes, so
# 145% tariffs on China, and that is basically an embargo. They deserve it. It'll raise prices on everything from
# electronics to clothing to building houses. You don't know that. You don't know whether or not China is going to
# eat it. That's mathematics. China probably will eat those tariffs, but at 145, they basically can't do much
# business with the United States. And they were making from us a trillion dollars a year. They were ripping us off
# like nobody's ever ripped us off. And by the way, we have other countries that were just as bad. If you look at the
# European Union, it was terrible what they've done to us. Every country, almost
#
# Out: None
# [Step 1: Duration 17.98 seconds| Input tokens: 2,147 | Output tokens: 90]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: I have the transcription of the first two minutes of the speech. Now I need to extract the key points from
# the text. The speech covers topics related to tariffs, the U.S. economy, transition period, trade relationships
# especially with China, and prices of goods like gasoline and groceries. I will summarize the main points to form
# the key takeaways.
#
# Code:
# ```py
# transcription_text = """Well, you said something a couple weeks ago that struck me. You said concerning the
# tariffs, which economists say are going to raise prices, you said, quote, hang tough, it won't be easy. You said
# that to the American people. Some hard times? I've said that during my campaign. Look, we won a campaign by a lot.
# We won all seven swing states. We won the popular vote by a lot. You know, we had a tremendous campaign. I said all
# these things during my campaign. I said, you're going to have a transition period. We've been ripped off by every
# country all over the world. They're laughing at us. They thought we were stupid people, and we were. And I said,
# that's not going to happen. We're not going to let that happen. Hard times are ahead? I don't think so. I think
# great times are ahead. Look, since I came in, gasoline is down, groceries are down, egg prices are down, many
# things are down, just about everything. You know, you don't have the drop in fuel and energy and oil like we did. I
# took it from maybe $3.20, maybe more than that, down into a much lower number. When you have that kind of a drop,
# you're not going to have inflation. Not now, but it's the tariffs, right? We still have 145% tariffs on China. Your
# Treasury Secretary said we basically have an embargo on China. Look, you're trying to say something's going to
# happen, Terry. No, no. Nothing's going to happen. You know business. I want to ask you. I do know business. Yes, so
# 145% tariffs on China, and that is basically an embargo. They deserve it. It'll raise prices on everything from
# electronics to clothing to building houses. You don't know that. You don't know whether or not China is going to
# eat it. That's mathematics. China probably will eat those tariffs, but at 145, they basically can't do much
# business with the United States. And they were making from us a trillion dollars a year. They were ripping us off
# like nobody's ever ripped us off. And by the way, we have other countries that were just as bad. If you look at the
# European Union, it was terrible what they've done to us. Every country, almost"""
# key_points = [
#     "Acknowledges concerns about tariffs potentially raising prices but urges 'hang tough' and reassures it won't
# be easy.",
#     "Claims a strong campaign victory including winning key swing states and the popular vote.",
#     "Mentions a transition period ahead as part of campaign promises.",
#     "States that the U.S. has been economically exploited by other countries and this will change.",
#     "Believes that great times are ahead, not hard times.",
#     "Highlights reductions in gasoline, groceries, egg prices, and energy costs since taking office.",
#     "Discusses high tariffs on China (145%) described as nearly an embargo.",
#     "Claims China was unfairly benefiting with a trillion dollars worth of trade advantage.",
#     "Suggests tariffs may raise prices but China might absorb the impact.",
#     "Mentions grievances with other trading partners like the European Union."
# ]
# print(key_points)
# ```<end_code>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   transcription_text = """Well, you said something a couple weeks ago that struck me. You said concerning the
#   tariffs, which economists say are going to raise prices, you said, quote, hang tough, it won't be easy. You
#   said that to the American people. Some hard times? I've said that during my campaign. Look, we won a campaign
#   by a lot. We won all seven swing states. We won the popular vote by a lot. You know, we had a tremendous
#   campaign. I said all these things during my campaign. I said, you're going to have a transition period. We've
#   been ripped off by every country all over the world. They're laughing at us. They thought we were stupid
#   people, and we were. And I said, that's not going to happen. We're not going to let that happen. Hard times are
#   ahead? I don't think so. I think great times are ahead. Look, since I came in, gasoline is down, groceries are
#   down, egg prices are down, many things are down, just about everything. You know, you don't have the drop in
#   fuel and energy and oil like we did. I took it from maybe $3.20, maybe more than that, down into a much lower
#   number. When you have that kind of a drop, you're not going to have inflation. Not now, but it's the tariffs,
#   right? We still have 145% tariffs on China. Your Treasury Secretary said we basically have an embargo on China.
#   Look, you're trying to say something's going to happen, Terry. No, no. Nothing's going to happen. You know
#   business. I want to ask you. I do know business. Yes, so 145% tariffs on China, and that is basically an
#   embargo. They deserve it. It'll raise prices on everything from electronics to clothing to building houses. You
#   don't know that. You don't know whether or not China is going to eat it. That's mathematics. China probably
#   will eat those tariffs, but at 145, they basically can't do much business with the United States. And they were
#   making from us a trillion dollars a year. They were ripping us off like nobody's ever ripped us off. And by the
#   way, we have other countries that were just as bad. If you look at the European Union, it was terrible what
#   they've done to us. Every country, almost"""
#   key_points = [
#       "Acknowledges concerns about tariffs potentially raising prices but urges 'hang tough' and reassures it
#   won't be easy.",
#       "Claims a strong campaign victory including winning key swing states and the popular vote.",
#       "Mentions a transition period ahead as part of campaign promises.",
#       "States that the U.S. has been economically exploited by other countries and this will change.",
#       "Believes that great times are ahead, not hard times.",
#       "Highlights reductions in gasoline, groceries, egg prices, and energy costs since taking office.",
#       "Discusses high tariffs on China (145%) described as nearly an embargo.",
#       "Claims China was unfairly benefiting with a trillion dollars worth of trade advantage.",
#       "Suggests tariffs may raise prices but China might absorb the impact.",
#       "Mentions grievances with other trading partners like the European Union."
#   ]
#   print(key_points)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ["Acknowledges concerns about tariffs potentially raising prices but urges 'hang tough' and reassures it won't be
# easy.", 'Claims a strong campaign victory including winning key swing states and the popular vote.', 'Mentions a
# transition period ahead as part of campaign promises.', 'States that the U.S. has been economically exploited by
# other countries and this will change.', 'Believes that great times are ahead, not hard times.', 'Highlights
# reductions in gasoline, groceries, egg prices, and energy costs since taking office.', 'Discusses high tariffs on
# China (145%) described as nearly an embargo.', 'Claims China was unfairly benefiting with a trillion dollars worth
# of trade advantage.', 'Suggests tariffs may raise prices but China might absorb the impact.', 'Mentions grievances
# with other trading partners like the European Union.']
#
# Out: None
# [Step 2: Duration 7.86 seconds| Input tokens: 4,956 | Output tokens: 827]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: I have successfully extracted the key points of Trump's speech from the transcription. I will now provide
# this list of key points as the final answer.
#
# Code:
# ```py
# final_key_points = [
#     "Acknowledges concerns about tariffs potentially raising prices but urges 'hang tough' and reassures it won't
# be easy.",
#     "Claims a strong campaign victory including winning key swing states and the popular vote.",
#     "Mentions a transition period ahead as part of campaign promises.",
#     "States that the U.S. has been economically exploited by other countries and this will change.",
#     "Believes that great times are ahead, not hard times.",
#     "Highlights reductions in gasoline, groceries, egg prices, and energy costs since taking office.",
#     "Discusses high tariffs on China (145%) described as nearly an embargo.",
#     "Claims China was unfairly benefiting with a trillion dollars worth of trade advantage.",
#     "Suggests tariffs may raise prices but China might absorb the impact.",
#     "Mentions grievances with other trading partners like the European Union."
# ]
# final_answer(final_key_points)
# ```<end_code>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_key_points = [
#       "Acknowledges concerns about tariffs potentially raising prices but urges 'hang tough' and reassures it
#   won't be easy.",
#       "Claims a strong campaign victory including winning key swing states and the popular vote.",
#       "Mentions a transition period ahead as part of campaign promises.",
#       "States that the U.S. has been economically exploited by other countries and this will change.",
#       "Believes that great times are ahead, not hard times.",
#       "Highlights reductions in gasoline, groceries, egg prices, and energy costs since taking office.",
#       "Discusses high tariffs on China (145%) described as nearly an embargo.",
#       "Claims China was unfairly benefiting with a trillion dollars worth of trade advantage.",
#       "Suggests tariffs may raise prices but China might absorb the impact.",
#       "Mentions grievances with other trading partners like the European Union."
#   ]
#   final_answer(final_key_points)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Out - Final answer: ["Acknowledges concerns about tariffs potentially raising prices but urges 'hang tough' and
# reassures it won't be easy.", 'Claims a strong campaign victory including winning key swing states and the popular
# vote.', 'Mentions a transition period ahead as part of campaign promises.', 'States that the U.S. has been
# economically exploited by other countries and this will change.', 'Believes that great times are ahead, not hard
# times.', 'Highlights reductions in gasoline, groceries, egg prices, and energy costs since taking office.',
# 'Discusses high tariffs on China (145%) described as nearly an embargo.', 'Claims China was unfairly benefiting
# with a trillion dollars worth of trade advantage.', 'Suggests tariffs may raise prices but China might absorb the
# impact.', 'Mentions grievances with other trading partners like the European Union.']
# [Step 3: Duration 3.28 seconds| Input tokens: 9,447 | Output tokens: 1,046]
